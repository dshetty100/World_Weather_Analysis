# %% [markdown]
# ### Deliverable 1. Retrieving weather data from various cities around the world

# %%
# Import the dependencies.
import pandas as pd
import numpy as np

# %% [markdown]
# ### Generating 2000 random latitudes and longitudes for various cities around the world

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude from above
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 604

# %% [markdown]
# ### Getting the weather data from a website using API and storing it in a list "city_data"

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# handling errors while parsing weather data from a JSON file using try-except
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
    
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country":city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | victoria
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | farah
# Processing Record 5 of Set 1 | vilyuysk
# Processing Record 6 of Set 1 | micheweni
# Processing Record 7 of Set 1 | sinnamary
# Processing Record 8 of Set 1 | uige
# Processing Record 9 of Set 1 | arraial do cabo
# Processing Record 10 of Set 1 | hobart
# Processing Record 11 of Set 1 | emerald
# Processing Record 12 of Set 1 | cape town
# Processing Record 13 of Set 1 | tiksi
# Processing Record 14 of Set 1 | vila velha
# Processing Record 15 of Set 1 | tuktoyaktuk
# Processing Record 16 of Set 1 | kirakira
# Processing Record 17 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 1 | atuona
# Processing Record 19 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 21 of Set 1 | kayes
# Processing Record 22 of Set 1 | codrington
# Processing Record 23 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 1 | mar del plata
# Processing Record 25 of Set 1 | new norfolk
# Processing Record 26 of Set 1 | bredasdorp
# Processing Record 27 of Set 1 | sri aman
# Processing Record 28 of Set 1 | severo-kurilsk
# Processing Record 29 of Set 1 | diego de almagro
# Processing Record 30 of Set 1 | ndele
# Processing Record 31 of Set 1 | soyo
# Processing Record 32 of Set 1 | mataura
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | kahului
# Processing Record 35 of Set 1 | wageningen
# Processing Record 36 of Set 1 | pangnirtung
# Processing Record 37 of Set 1 | azare
# Processing Record 38 of Set 1 | jamestown
# Processing Record 39 of Set 1 | shenjiamen
# Processing Record 40 of Set 1 | kavieng
# Processing Record 41 of Set 1 | nikolskoye
# Processing Record 42 of Set 1 | hilo
# Processing Record 43 of Set 1 | harper
# Processing Record 44 of Set 1 | saldanha
# Processing Record 45 of Set 1 | hermanus
# Processing Record 46 of Set 1 | punta arenas
# Processing Record 47 of Set 1 | malwan
# City not found. Skipping...
# Processing Record 48 of Set 1 | meadow lake
# Processing Record 49 of Set 1 | neryungri
# Processing Record 50 of Set 1 | thompson
# Processing Record 1 of Set 2 | saskylakh
# Processing Record 2 of Set 2 | castro
# Processing Record 3 of Set 2 | san pedro de macoris
# Processing Record 4 of Set 2 | vila franca do campo
# Processing Record 5 of Set 2 | tuatapere
# Processing Record 6 of Set 2 | benjamin constant
# Processing Record 7 of Set 2 | esperance
# Processing Record 8 of Set 2 | barrow
# Processing Record 9 of Set 2 | cradock
# Processing Record 10 of Set 2 | hithadhoo
# Processing Record 11 of Set 2 | ijaki
# City not found. Skipping...
# Processing Record 12 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 2 | klaksvik
# Processing Record 14 of Set 2 | statesboro
# Processing Record 15 of Set 2 | ariquemes
# Processing Record 16 of Set 2 | sao filipe
# Processing Record 17 of Set 2 | riyadh
# Processing Record 18 of Set 2 | gat
# Processing Record 19 of Set 2 | whitehorse
# Processing Record 20 of Set 2 | albany
# Processing Record 21 of Set 2 | muravlenko
# Processing Record 22 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 2 | mantua
# Processing Record 24 of Set 2 | sao francisco do sul
# Processing Record 25 of Set 2 | iqaluit
# Processing Record 26 of Set 2 | mahebourg
# Processing Record 27 of Set 2 | nyurba
# Processing Record 28 of Set 2 | vao
# Processing Record 29 of Set 2 | cabo san lucas
# Processing Record 30 of Set 2 | cidreira
# Processing Record 31 of Set 2 | qaanaaq
# Processing Record 32 of Set 2 | jumla
# Processing Record 33 of Set 2 | port alfred
# Processing Record 34 of Set 2 | northam
# Processing Record 35 of Set 2 | dikson
# Processing Record 36 of Set 2 | mokhsogollokh
# Processing Record 37 of Set 2 | sawtell
# Processing Record 38 of Set 2 | taft
# Processing Record 39 of Set 2 | kapaa
# Processing Record 40 of Set 2 | paithan
# Processing Record 41 of Set 2 | ingleside
# Processing Record 42 of Set 2 | hofn
# Processing Record 43 of Set 2 | tasiilaq
# Processing Record 44 of Set 2 | cherskiy
# Processing Record 45 of Set 2 | sopot
# Processing Record 46 of Set 2 | zurrieq
# Processing Record 47 of Set 2 | yellowknife
# Processing Record 48 of Set 2 | luba
# Processing Record 49 of Set 2 | lebu
# Processing Record 50 of Set 2 | vestmannaeyjar
# Processing Record 1 of Set 3 | ilulissat
# Processing Record 2 of Set 3 | husavik
# Processing Record 3 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 4 of Set 3 | ahipara
# Processing Record 5 of Set 3 | san patricio
# Processing Record 6 of Set 3 | camargo
# Processing Record 7 of Set 3 | puerto ayora
# Processing Record 8 of Set 3 | east london
# Processing Record 9 of Set 3 | turbat
# Processing Record 10 of Set 3 | georgetown
# Processing Record 11 of Set 3 | paamiut
# Processing Record 12 of Set 3 | pudozh
# Processing Record 13 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 14 of Set 3 | portland
# Processing Record 15 of Set 3 | ribeira grande
# Processing Record 16 of Set 3 | vila
# Processing Record 17 of Set 3 | lasa
# Processing Record 18 of Set 3 | namatanai
# Processing Record 19 of Set 3 | port elizabeth
# Processing Record 20 of Set 3 | ola
# Processing Record 21 of Set 3 | pilar do sul
# Processing Record 22 of Set 3 | pacific grove
# Processing Record 23 of Set 3 | birao
# Processing Record 24 of Set 3 | vaini
# Processing Record 25 of Set 3 | tezu
# Processing Record 26 of Set 3 | cayenne
# Processing Record 27 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 3 | kavaratti
# Processing Record 29 of Set 3 | haines junction
# Processing Record 30 of Set 3 | hasaki
# Processing Record 31 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 3 | pansemal
# Processing Record 33 of Set 3 | valence
# Processing Record 34 of Set 3 | normandin
# Processing Record 35 of Set 3 | coihaique
# Processing Record 36 of Set 3 | yarmouth
# Processing Record 37 of Set 3 | dalmeny
# Processing Record 38 of Set 3 | campoverde
# Processing Record 39 of Set 3 | salalah
# Processing Record 40 of Set 3 | te anau
# Processing Record 41 of Set 3 | laguna
# Processing Record 42 of Set 3 | los llanos de aridane
# Processing Record 43 of Set 3 | torbay
# Processing Record 44 of Set 3 | varkkallai
# Processing Record 45 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 3 | upernavik
# Processing Record 47 of Set 3 | slonim
# Processing Record 48 of Set 3 | san quintin
# Processing Record 49 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 3 | luderitz
# Processing Record 1 of Set 4 | parksville
# Processing Record 2 of Set 4 | bethel
# Processing Record 3 of Set 4 | fare
# Processing Record 4 of Set 4 | rocha
# Processing Record 5 of Set 4 | lufilufi
# Processing Record 6 of Set 4 | saint anthony
# Processing Record 7 of Set 4 | carnarvon
# Processing Record 8 of Set 4 | bluff
# Processing Record 9 of Set 4 | bowling green
# Processing Record 10 of Set 4 | altay
# Processing Record 11 of Set 4 | alzamay
# Processing Record 12 of Set 4 | kruisfontein
# Processing Record 13 of Set 4 | chutove
# Processing Record 14 of Set 4 | mackay
# Processing Record 15 of Set 4 | lavrentiya
# Processing Record 16 of Set 4 | cienfuegos
# Processing Record 17 of Set 4 | la ronge
# Processing Record 18 of Set 4 | wembley
# Processing Record 19 of Set 4 | beckley
# Processing Record 20 of Set 4 | valle de juarez
# Processing Record 21 of Set 4 | masuguru
# Processing Record 22 of Set 4 | bull savanna
# Processing Record 23 of Set 4 | kloulklubed
# Processing Record 24 of Set 4 | lorengau
# Processing Record 25 of Set 4 | coquimbo
# Processing Record 26 of Set 4 | provideniya
# Processing Record 27 of Set 4 | butaritari
# Processing Record 28 of Set 4 | limbang
# Processing Record 29 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 4 | valle de allende
# Processing Record 33 of Set 4 | ise
# Processing Record 34 of Set 4 | girne
# Processing Record 35 of Set 4 | thinadhoo
# Processing Record 36 of Set 4 | methoni
# Processing Record 37 of Set 4 | vanimo
# Processing Record 38 of Set 4 | bonavista
# Processing Record 39 of Set 4 | mujiayingzi
# Processing Record 40 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 41 of Set 4 | namibe
# Processing Record 42 of Set 4 | prince rupert
# Processing Record 43 of Set 4 | poum
# Processing Record 44 of Set 4 | jackson
# Processing Record 45 of Set 4 | carquefou
# Processing Record 46 of Set 4 | vagur
# Processing Record 47 of Set 4 | fort nelson
# Processing Record 48 of Set 4 | ketchikan
# Processing Record 49 of Set 4 | tessalit
# Processing Record 50 of Set 4 | ancud
# Processing Record 1 of Set 5 | sinjar
# Processing Record 2 of Set 5 | atar
# Processing Record 3 of Set 5 | flinders
# Processing Record 4 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 5 of Set 5 | sao joao da barra
# Processing Record 6 of Set 5 | nanortalik
# Processing Record 7 of Set 5 | inta
# Processing Record 8 of Set 5 | san carlos de bariloche
# Processing Record 9 of Set 5 | elwood
# Processing Record 10 of Set 5 | longyearbyen
# Processing Record 11 of Set 5 | olinda
# Processing Record 12 of Set 5 | chuy
# Processing Record 13 of Set 5 | kaeo
# Processing Record 14 of Set 5 | sai buri
# Processing Record 15 of Set 5 | salinopolis
# Processing Record 16 of Set 5 | nayoro
# Processing Record 17 of Set 5 | gewane
# Processing Record 18 of Set 5 | tanabi
# Processing Record 19 of Set 5 | pandegelang
# Processing Record 20 of Set 5 | snezhnogorsk
# Processing Record 21 of Set 5 | norman wells
# Processing Record 22 of Set 5 | faya
# Processing Record 23 of Set 5 | orchard homes
# Processing Record 24 of Set 5 | nelson bay
# Processing Record 25 of Set 5 | sturgeon bay
# Processing Record 26 of Set 5 | meulaboh
# Processing Record 27 of Set 5 | guerrero negro
# Processing Record 28 of Set 5 | paris
# Processing Record 29 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 5 | cockburn town
# Processing Record 31 of Set 5 | jalu
# Processing Record 32 of Set 5 | coruripe
# Processing Record 33 of Set 5 | pangody
# Processing Record 34 of Set 5 | parakai
# Processing Record 35 of Set 5 | taganak
# Processing Record 36 of Set 5 | progreso
# Processing Record 37 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 38 of Set 5 | kovdor
# Processing Record 39 of Set 5 | acapulco
# Processing Record 40 of Set 5 | lima
# Processing Record 41 of Set 5 | pevek
# Processing Record 42 of Set 5 | saint-philippe
# Processing Record 43 of Set 5 | khatanga
# Processing Record 44 of Set 5 | ponta delgada
# Processing Record 45 of Set 5 | jiayuguan
# Processing Record 46 of Set 5 | bathsheba
# Processing Record 47 of Set 5 | bintulu
# Processing Record 48 of Set 5 | dukuhturi
# Processing Record 49 of Set 5 | saint george
# Processing Record 50 of Set 5 | zherdevka
# Processing Record 1 of Set 6 | morgan city
# Processing Record 2 of Set 6 | maragogi
# Processing Record 3 of Set 6 | ponta do sol
# Processing Record 4 of Set 6 | aasiaat
# Processing Record 5 of Set 6 | lompoc
# Processing Record 6 of Set 6 | alice springs
# Processing Record 7 of Set 6 | kodiak
# Processing Record 8 of Set 6 | xai-xai
# Processing Record 9 of Set 6 | muktagachha
# City not found. Skipping...
# Processing Record 10 of Set 6 | altamura
# Processing Record 11 of Set 6 | aksarka
# Processing Record 12 of Set 6 | broome
# Processing Record 13 of Set 6 | fereydun kenar
# Processing Record 14 of Set 6 | chokurdakh
# Processing Record 15 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 6 | manzhouli
# Processing Record 17 of Set 6 | caluquembe
# Processing Record 18 of Set 6 | terrace
# Processing Record 19 of Set 6 | bakel
# Processing Record 20 of Set 6 | marzuq
# Processing Record 21 of Set 6 | okhotsk
# Processing Record 22 of Set 6 | marawi
# Processing Record 23 of Set 6 | kawalu
# Processing Record 24 of Set 6 | orneta
# Processing Record 25 of Set 6 | north bend
# Processing Record 26 of Set 6 | avarua
# Processing Record 27 of Set 6 | pietersburg
# Processing Record 28 of Set 6 | korla
# Processing Record 29 of Set 6 | oyama
# Processing Record 30 of Set 6 | venado tuerto
# Processing Record 31 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 32 of Set 6 | muisne
# Processing Record 33 of Set 6 | abu dhabi
# Processing Record 34 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 35 of Set 6 | kegayli
# City not found. Skipping...
# Processing Record 36 of Set 6 | muros
# Processing Record 37 of Set 6 | beyneu
# Processing Record 38 of Set 6 | faanui
# Processing Record 39 of Set 6 | lensk
# Processing Record 40 of Set 6 | phalombe
# Processing Record 41 of Set 6 | purpe
# Processing Record 42 of Set 6 | cairns
# Processing Record 43 of Set 6 | merauke
# Processing Record 44 of Set 6 | ampanihy
# Processing Record 45 of Set 6 | atherton
# Processing Record 46 of Set 6 | miandoab
# Processing Record 47 of Set 6 | aranos
# Processing Record 48 of Set 6 | antalaha
# Processing Record 49 of Set 6 | adrar
# Processing Record 50 of Set 6 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 1 of Set 7 | gamba
# Processing Record 2 of Set 7 | lodja
# Processing Record 3 of Set 7 | rio brilhante
# Processing Record 4 of Set 7 | takoradi
# Processing Record 5 of Set 7 | pedernales
# Processing Record 6 of Set 7 | kabelvag
# Processing Record 7 of Set 7 | agirish
# Processing Record 8 of Set 7 | pacasmayo
# Processing Record 9 of Set 7 | morant bay
# Processing Record 10 of Set 7 | leavenworth
# Processing Record 11 of Set 7 | buchanan
# Processing Record 12 of Set 7 | clyde river
# Processing Record 13 of Set 7 | camabatela
# Processing Record 14 of Set 7 | souris
# Processing Record 15 of Set 7 | port hardy
# Processing Record 16 of Set 7 | santiago
# Processing Record 17 of Set 7 | aykhal
# Processing Record 18 of Set 7 | hazorasp
# Processing Record 19 of Set 7 | biggar
# Processing Record 20 of Set 7 | antofagasta
# Processing Record 21 of Set 7 | alofi
# Processing Record 22 of Set 7 | matay
# Processing Record 23 of Set 7 | bokovskaya
# Processing Record 24 of Set 7 | nawa
# Processing Record 25 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 7 | rabo de peixe
# Processing Record 27 of Set 7 | watrous
# Processing Record 28 of Set 7 | wulanhaote
# City not found. Skipping...
# Processing Record 29 of Set 7 | killybegs
# Processing Record 30 of Set 7 | margate
# Processing Record 31 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 7 | bengkulu
# Processing Record 33 of Set 7 | bilaspur
# Processing Record 34 of Set 7 | padang
# Processing Record 35 of Set 7 | portobelo
# Processing Record 36 of Set 7 | fortuna
# Processing Record 37 of Set 7 | kendari
# Processing Record 38 of Set 7 | mabaruma
# Processing Record 39 of Set 7 | leningradskiy
# Processing Record 40 of Set 7 | lai
# Processing Record 41 of Set 7 | pisco
# Processing Record 42 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 43 of Set 7 | eyl
# Processing Record 44 of Set 7 | palmer
# Processing Record 45 of Set 7 | kupang
# Processing Record 46 of Set 7 | qinhuangdao
# Processing Record 47 of Set 7 | sharan
# Processing Record 48 of Set 7 | nara
# Processing Record 49 of Set 7 | neuquen
# Processing Record 50 of Set 7 | saint-joseph
# Processing Record 1 of Set 8 | nuuk
# Processing Record 2 of Set 8 | yulara
# Processing Record 3 of Set 8 | do gonbadan
# Processing Record 4 of Set 8 | tabukiniberu
# City not found. Skipping...
# Processing Record 5 of Set 8 | makakilo city
# Processing Record 6 of Set 8 | valparaiso
# Processing Record 7 of Set 8 | paka
# Processing Record 8 of Set 8 | manaure
# Processing Record 9 of Set 8 | porto novo
# Processing Record 10 of Set 8 | binzhou
# Processing Record 11 of Set 8 | gangotri
# City not found. Skipping...
# Processing Record 12 of Set 8 | alyangula
# Processing Record 13 of Set 8 | katobu
# Processing Record 14 of Set 8 | fairbanks
# Processing Record 15 of Set 8 | nizwa
# Processing Record 16 of Set 8 | talikota
# Processing Record 17 of Set 8 | novikovo
# Processing Record 18 of Set 8 | souillac
# Processing Record 19 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 20 of Set 8 | le vauclin
# Processing Record 21 of Set 8 | kenai
# Processing Record 22 of Set 8 | dalbandin
# Processing Record 23 of Set 8 | southbridge
# Processing Record 24 of Set 8 | taby
# Processing Record 25 of Set 8 | spornoye
# Processing Record 26 of Set 8 | didwana
# Processing Record 27 of Set 8 | dingle
# Processing Record 28 of Set 8 | kieta
# Processing Record 29 of Set 8 | sorland
# Processing Record 30 of Set 8 | grindavik
# Processing Record 31 of Set 8 | tabas
# Processing Record 32 of Set 8 | amga
# Processing Record 33 of Set 8 | anadyr
# Processing Record 34 of Set 8 | helong
# Processing Record 35 of Set 8 | kushima
# Processing Record 36 of Set 8 | higuey
# City not found. Skipping...
# Processing Record 37 of Set 8 | baykit
# Processing Record 38 of Set 8 | ostrovnoy
# Processing Record 39 of Set 8 | ramos arizpe
# Processing Record 40 of Set 8 | ornskoldsvik
# Processing Record 41 of Set 8 | port pirie
# Processing Record 42 of Set 8 | college
# Processing Record 43 of Set 8 | richards bay
# Processing Record 44 of Set 8 | alto araguaia
# Processing Record 45 of Set 8 | isangel
# Processing Record 46 of Set 8 | barra do corda
# Processing Record 47 of Set 8 | havre-saint-pierre
# Processing Record 48 of Set 8 | road town
# Processing Record 49 of Set 8 | warburton
# Processing Record 50 of Set 8 | abu samrah
# Processing Record 1 of Set 9 | trzebiatow
# Processing Record 2 of Set 9 | erzin
# Processing Record 3 of Set 9 | gardan diwal
# City not found. Skipping...
# Processing Record 4 of Set 9 | toamasina
# Processing Record 5 of Set 9 | axim
# Processing Record 6 of Set 9 | hambantota
# Processing Record 7 of Set 9 | guozhen
# Processing Record 8 of Set 9 | tucuma
# Processing Record 9 of Set 9 | manavalakurichi
# Processing Record 10 of Set 9 | sola
# Processing Record 11 of Set 9 | hobyo
# Processing Record 12 of Set 9 | shafranovo
# Processing Record 13 of Set 9 | lagoa
# Processing Record 14 of Set 9 | marau
# Processing Record 15 of Set 9 | bakloh
# Processing Record 16 of Set 9 | ca mau
# Processing Record 17 of Set 9 | haicheng
# Processing Record 18 of Set 9 | tautira
# Processing Record 19 of Set 9 | esil
# Processing Record 20 of Set 9 | kaseda
# Processing Record 21 of Set 9 | shimoda
# Processing Record 22 of Set 9 | gambela
# Processing Record 23 of Set 9 | nome
# Processing Record 24 of Set 9 | lixourion
# Processing Record 25 of Set 9 | karasuk
# Processing Record 26 of Set 9 | flin flon
# Processing Record 27 of Set 9 | bonfim
# Processing Record 28 of Set 9 | falealupo
# City not found. Skipping...
# Processing Record 29 of Set 9 | pahrump
# Processing Record 30 of Set 9 | staryy nadym
# Processing Record 31 of Set 9 | nizhniy tagil
# Processing Record 32 of Set 9 | along
# Processing Record 33 of Set 9 | andros town
# Processing Record 34 of Set 9 | khuzdar
# Processing Record 35 of Set 9 | tuggurt
# City not found. Skipping...
# Processing Record 36 of Set 9 | bow island
# Processing Record 37 of Set 9 | bambous virieux
# Processing Record 38 of Set 9 | acarau
# Processing Record 39 of Set 9 | ivanivka
# Processing Record 40 of Set 9 | martapura
# Processing Record 41 of Set 9 | cap malheureux
# Processing Record 42 of Set 9 | sechura
# Processing Record 43 of Set 9 | dubti
# Processing Record 44 of Set 9 | kaitangata
# Processing Record 45 of Set 9 | lincoln
# Processing Record 46 of Set 9 | san borja
# Processing Record 47 of Set 9 | ixtapa
# Processing Record 48 of Set 9 | chinsali
# Processing Record 49 of Set 9 | juneau
# Processing Record 50 of Set 9 | eidsvoll
# Processing Record 1 of Set 10 | ganganagar
# Processing Record 2 of Set 10 | giyani
# Processing Record 3 of Set 10 | kudahuvadhoo
# Processing Record 4 of Set 10 | cabedelo
# Processing Record 5 of Set 10 | aksarayskiy
# Processing Record 6 of Set 10 | airai
# Processing Record 7 of Set 10 | kandi
# Processing Record 8 of Set 10 | tasbuget
# City not found. Skipping...
# Processing Record 9 of Set 10 | mount gambier
# Processing Record 10 of Set 10 | colares
# Processing Record 11 of Set 10 | taltal
# Processing Record 12 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 10 | hualmay
# Processing Record 14 of Set 10 | port lincoln
# Processing Record 15 of Set 10 | houma
# Processing Record 16 of Set 10 | groningen
# Processing Record 17 of Set 10 | floresta
# Processing Record 18 of Set 10 | willowmore
# Processing Record 19 of Set 10 | pimenta bueno
# Processing Record 20 of Set 10 | bubaque
# Processing Record 21 of Set 10 | olafsvik
# Processing Record 22 of Set 10 | bonthe
# Processing Record 23 of Set 10 | pochutla
# Processing Record 24 of Set 10 | sur
# Processing Record 25 of Set 10 | mitsamiouli
# Processing Record 26 of Set 10 | turukhansk
# Processing Record 27 of Set 10 | oranjestad
# Processing Record 28 of Set 10 | ahmadpur east
# Processing Record 29 of Set 10 | erenhot
# Processing Record 30 of Set 10 | solsvik
# City not found. Skipping...
# Processing Record 31 of Set 10 | lysva
# Processing Record 32 of Set 10 | hamilton
# Processing Record 33 of Set 10 | daura
# Processing Record 34 of Set 10 | tadine
# Processing Record 35 of Set 10 | qui nhon
# Processing Record 36 of Set 10 | salinas
# Processing Record 37 of Set 10 | oistins
# Processing Record 38 of Set 10 | alferrarede
# Processing Record 39 of Set 10 | zimapan
# Processing Record 40 of Set 10 | talnakh
# Processing Record 41 of Set 10 | mahon
# Processing Record 42 of Set 10 | nouadhibou
# Processing Record 43 of Set 10 | zhigansk
# Processing Record 44 of Set 10 | owando
# Processing Record 45 of Set 10 | kalmunai
# Processing Record 46 of Set 10 | qeshm
# Processing Record 47 of Set 10 | tahe
# Processing Record 48 of Set 10 | mehamn
# Processing Record 49 of Set 10 | port hawkesbury
# Processing Record 50 of Set 10 | byron bay
# Processing Record 1 of Set 11 | dharur
# Processing Record 2 of Set 11 | trofors
# Processing Record 3 of Set 11 | sitka
# Processing Record 4 of Set 11 | mahaicony
# City not found. Skipping...
# Processing Record 5 of Set 11 | warrington
# Processing Record 6 of Set 11 | lebanon
# Processing Record 7 of Set 11 | brae
# Processing Record 8 of Set 11 | sedhiou
# Processing Record 9 of Set 11 | grand gaube
# Processing Record 10 of Set 11 | beira
# Processing Record 11 of Set 11 | katsuura
# Processing Record 12 of Set 11 | prainha
# Processing Record 13 of Set 11 | geraldton
# Processing Record 14 of Set 11 | saint-pierre
# Processing Record 15 of Set 11 | elizabeth city
# Processing Record 16 of Set 11 | nalagarh
# Processing Record 17 of Set 11 | mpulungu
# Processing Record 18 of Set 11 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 19 of Set 11 | bojnurd
# Processing Record 20 of Set 11 | joshimath
# Processing Record 21 of Set 11 | srednekolymsk
# Processing Record 22 of Set 11 | dossor
# Processing Record 23 of Set 11 | batangafo
# Processing Record 24 of Set 11 | dubbo
# Processing Record 25 of Set 11 | werda
# Processing Record 26 of Set 11 | poronaysk
# Processing Record 27 of Set 11 | mogadishu
# Processing Record 28 of Set 11 | nisia floresta
# Processing Record 29 of Set 11 | praia da vitoria
# Processing Record 30 of Set 11 | kiama
# Processing Record 31 of Set 11 | mahanoro
# Processing Record 32 of Set 11 | saint-augustin
# Processing Record 33 of Set 11 | la cruz
# Processing Record 34 of Set 11 | san diego de los banos
# Processing Record 35 of Set 11 | iaciara
# Processing Record 36 of Set 11 | kuantan
# Processing Record 37 of Set 11 | viedma
# Processing Record 38 of Set 11 | santa cruz cabralia
# Processing Record 39 of Set 11 | yumen
# Processing Record 40 of Set 11 | bud
# Processing Record 41 of Set 11 | lotofaga
# Processing Record 42 of Set 11 | jardim
# Processing Record 43 of Set 11 | tahoua
# Processing Record 44 of Set 11 | honiara
# Processing Record 45 of Set 11 | mandalgovi
# Processing Record 46 of Set 11 | noumea
# Processing Record 47 of Set 11 | imperial
# Processing Record 48 of Set 11 | samarai
# Processing Record 49 of Set 11 | tupik
# Processing Record 50 of Set 11 | kincardine
# Processing Record 1 of Set 12 | carutapera
# Processing Record 2 of Set 12 | evensk
# Processing Record 3 of Set 12 | manokwari
# Processing Record 4 of Set 12 | greystones
# Processing Record 5 of Set 12 | port hedland
# Processing Record 6 of Set 12 | gunjur
# Processing Record 7 of Set 12 | shkotovo-22
# City not found. Skipping...
# Processing Record 8 of Set 12 | orumiyeh
# Processing Record 9 of Set 12 | gusinoye ozero
# Processing Record 10 of Set 12 | ayr
# Processing Record 11 of Set 12 | bosaso
# Processing Record 12 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 13 of Set 12 | ossora
# Processing Record 14 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 15 of Set 12 | winnipeg
# Processing Record 16 of Set 12 | owosso
# Processing Record 17 of Set 12 | craig
# Processing Record 18 of Set 12 | kodinsk
# Processing Record 19 of Set 12 | constitucion
# Processing Record 20 of Set 12 | mangrol
# Processing Record 21 of Set 12 | vila do maio
# Processing Record 22 of Set 12 | barkot
# Processing Record 23 of Set 12 | half moon bay
# Processing Record 24 of Set 12 | komsomolskiy
# Processing Record 25 of Set 12 | mattru
# Processing Record 26 of Set 12 | gazanjyk
# Processing Record 27 of Set 12 | beringovskiy
# Processing Record 28 of Set 12 | safranbolu
# Processing Record 29 of Set 12 | tres arroyos
# Processing Record 30 of Set 12 | preeceville
# Processing Record 31 of Set 12 | bourail
# Processing Record 32 of Set 12 | cartagena
# Processing Record 33 of Set 12 | sobolevo
# Processing Record 34 of Set 12 | smidovich
# Processing Record 35 of Set 12 | oron
# Processing Record 36 of Set 12 | bani walid
# Processing Record 37 of Set 12 | omboue
# Processing Record 38 of Set 12 | diapaga
# Processing Record 39 of Set 12 | lidkoping
# Processing Record 40 of Set 12 | ambon
# Processing Record 41 of Set 12 | phnum penh
# City not found. Skipping...
# Processing Record 42 of Set 12 | cabatuan
# Processing Record 43 of Set 12 | neiafu
# Processing Record 44 of Set 12 | kiknur
# Processing Record 45 of Set 12 | humaita
# Processing Record 46 of Set 12 | voi
# Processing Record 47 of Set 12 | carauari
# Processing Record 48 of Set 12 | itarema
# Processing Record 49 of Set 12 | acajutla
# Processing Record 50 of Set 12 | almaznyy
# Processing Record 1 of Set 13 | yarada
# Processing Record 2 of Set 13 | santa isabel
# Processing Record 3 of Set 13 | iquique
# Processing Record 4 of Set 13 | bargal
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Converting the array of dictionaries (city_data, which has all the data from API) to Pandas DataFrame

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Victoria      HK  22.2855  114.1577     85.32        86          83
# 1          Rikitea      PF -23.1203 -134.9692     74.07        70           9
# 2        Busselton      AU -33.6500  115.3333     48.09        76           0
# 3            Farah      AF  32.5000   62.5000     79.61        10           0
# 4         Vilyuysk      RU  63.7553  121.6247     39.72        76         100
# 5        Micheweni      TZ  -4.9667   39.8333     76.69        78           7
# 6        Sinnamary      GF   5.3833  -52.9500     87.80        59          36
# 7             Uige      AO  -7.6087   15.0613     80.17        55          87
# 8  Arraial Do Cabo      BR -22.9661  -42.0278     71.46        56          75
# 9           Hobart      AU -42.8794  147.3294     51.26        70          47
#
#    Wind Speed Current Description
# 0       17.74          light rain
# 1       23.53           clear sky
# 2       11.88           clear sky
# 3        2.53           clear sky
# 4        3.56     overcast clouds
# 5       10.38           clear sky
# 6       11.65    scattered clouds
# 7        4.56     overcast clouds
# 8        9.22       broken clouds
# 9        6.91    scattered clouds

# %% [markdown]
# ### Exporting the DataFrame to a comma-separated (CSV) file.

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
